# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

# 建立 Service 物件，指定 chromedriver.exe 的路徑
service = Service('./chromedriver.exe')

# 設定 Chrome 瀏覽器的選項
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized") # Chrome 瀏覽器在啟動時最大化視窗
options.add_argument("--incognito") # 無痕模式
options.add_argument("--disable-popup-blocking") # 停用 Chrome 的彈窗阻擋功能。

# 建立 Chrome 瀏覽器物件
driver = webdriver.Chrome(service=service, options=options)
driver.get("https://today.line.me/tw/v2/movie/incinemas/playing")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       2 from selenium.webdriver.common.by import By
#       4 # 建立 Service 物件，指定 chromedriver.exe 的路徑
# ----> 5 service = Service('./chromedriver.exe')
#       7 # 設定 Chrome 瀏覽器的選項
#       8 options = webdriver.ChromeOptions()
#
# NameError: name 'Service' is not defined

# %%
movie_list = driver.find_elements(By.CSS_SELECTOR,".detailListItem.movieListing-movie")

# %%
print(len(movie_list))
# Out:
# 20

# %%
import time

movie_list = driver.find_elements(By.CSS_SELECTOR,".detailListItem.movieListing-movie")

print(f"目前數量: {len(movie_list)}")

while True:
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)
    # 取得新的元素
    movie_list = driver.find_elements(By.CSS_SELECTOR,".detailListItem.movieListing-movie")
    if last_movie == movie_list[-1]:
        break

    last_movie = movie_list[-1]
    print(f"目前數量: {len(movie_list)}")

all_movie_info = []
for movie in movie_list:
    movie_name =  movie.find_element(By.CSS_SELECTOR, ".detailListItem-details .detailListItem-titles").text
    movie_grade = movie.find_element(By.CSS_SELECTOR, ".iconInfo.detailListItem-iconInfo").text
    movie_time = movie.find_element(By.CSS_SELECTOR, ".detailListItem-status > span").text
    movie_link = movie.find_element(By.CSS_SELECTOR, ".detailListItem-bookingButton").get_attribute("href")

    all_movie_info.append({
        "name" : movie_name,
        "grade" : movie_grade,
        "time" : movie_time,
        "link" : movie_link
    })
print(all_movie_info)
# Out:
# 目前數量: 95
# [{'name': '終極戰士：殺戮星球\nPredator: Badlands', 'grade': '9.1', 'time': '• 1小時47分 • 2025年11月06日上映', 'link': 'https://today.line.me/tw/v3/movie/5y7K1gV/1'}, {'name': '劇場版『鏈鋸人 蕾潔篇』\nChainsaw Man – The Movie: Reze Arc', 'grade': '9.1', 'time': '• 1小時40分 • 2025年09月24日上映', 'link': 'https://today.line.me/tw/v3/movie/qo9a3zy/1'}, {'name': '泥娃娃\nMudborn', 'grade': '8.6', 'time': '• 1小時51分 • 2025年10月09日上映', 'link': 'https://today.line.me/tw/v3/movie/OpgpXxj/1'}, {'name': '自殺通告\nDeadline', 'grade': '7.6', 'time': '• 1小時57分 • 2025年11月07日上映', 'link': 'https://today.line.me/tw/v3/movie/YavOK1M/1'}, {'name': '國寶\nKOKUHO', 'grade': '9.3', 'time': '• 2小時55分 • 2025年10月23日上映', 'link': 'https://today.line.me/tw/v3/movie/60n71q6/1'}, {'name': '96分鐘\n96 Minutes', 'grade': '8.7', 'time': '• 1小時58分 • 2025年09月05日上映', '
術\nThe Alchemy of The Piano', 'grade': '0.0', 'time': '• 1小時30分 • 2025年11月07日上映', 'link': 'https://today.line.me/tw/v3/movie/gzrm31N/1'}, {'name': '蟲\nLocust', 'grade': '8.0', 'time': '• 2小時15分 • 2025年11月07日上映', 'link': 'https://today.line.me/tw/v3/movie/BE35DZz/1'}, {'name': '電影版吸吸吸吸吸血鬼\nBabanba Banban Vampire', 'grade': '10', 'time': '• 1小時45分 • 2025年11月07日上映', 'link': 'https://today.line.me/tw/v3/movie/60napRa/1'}, {'name': '碰碰狐和貝貝彬歡唱電影：奇幻世界大冒險\nBebefinn Sing-Along Movie: Into the Pinkfong World', 'grade': '9.0', 'time': '• 1小時05分 • 2025年10月09日上映', 'link': 'https://today.line.me/tw/v3/movie/BE38mR6/1'}, {'name': '我們意外的勇氣\nUnexpected Courage', 'grade': '9.1', 'time': '• 1小時51分 • 2025年10月23日上映', 'link': 'https://today.line.me/tw/v3/movie/60lz2mX/1'}, {'name': '未完的情歌\nLOVE SONG', 'grade': '0.0', 'time': '• 1小時59分 • 2025年11月07日上映', 'link': 'https://today.line.me/tw/v3/movie/BE3Kk06/1'}, {'name': '捍衛天使\nGood Fortune', 'grade': '8.6', 't ...

# %%
print(movie_list[-1].get_attribute("outerHTML"))
# Out:
# <div data-v-3303a5bf="" data-v-3fe14e18="" class="detailListItem movieListing-movie"><div data-v-3303a5bf="" class="detailListItem-images"><div data-v-3303a5bf="" class="detailListItem-poster"><figure data-v-74a4a710="" data-v-3303a5bf="" class="detailListItem-posterImage backgroundImage backgroundImage--poster backgroundImage--movie backgroundImage--cover" data-src="https://today-obs.line-scdn.net/0hQgyqqcSiDkhECBD4D-ZxHxheDSd3ZB1LID5ffDoJFQRqMBV2EQpFURR7UwcPWwJOMAUKTwdJFgcxU0h_Hg4dewQJGSgPUEhNERUBfT1KUBAPag9lJDRJUhE/w280" lazy="loaded" style="background-image: url(&quot;https://today-obs.line-scdn.net/0hQgyqqcSiDkhECBD4D-ZxHxheDSd3ZB1LID5ffDoJFQRqMBV2EQpFURR7UwcPWwJOMAUKTwdJFgcxU0h_Hg4dewQJGSgPUEhNERUBfT1KUBAPag9lJDRJUhE/w280&quot;);"></figure></div> <a data-v-3303a5bf="" href="/tw/v3/article/Kwmvxek" class="detailListItem-trailer"><figure data-v-74a4a710="" data-v-3303a5bf="" class="backgroundImage backgroundImage--poster backgroundImage--landscape backgroundImage--cover detailListItem-trailerImage" data-src="https://today-obs.line-scdn.net/0hftfyFcxDOVtbACfTWKBGDAdWOjRobCpYPzZobyUBIhR0UDheZDh2QSFwYxUQSz1dFQ09XBhBIRQuW39sAQYqaBsBLjsQdX5mZAZ1biJ8ZxcqYjh2Ozx-QQ4/w580" lazy="loaded" style="background-image: url(&quot;https://today-obs.line-scdn.net/0hftfyFcxDOVtbACfTWKBGDAdWOjRobCpYPzZobyUBIhR0UDheZDh2QSFwYxUQSz1dFQ09XBhBIRQuW39sAQYqaBsBLjsQdX5mZAZ1biJ8ZxcqYjh2Ozx-QQ4/w580&quot;);"></figure> <div data-v-93e2444c="" data-v-6d1c5278="" data-v-3303a5bf="" class="detailListItem-trailerBadge glnBadge glnBadge--primary glnBadge--onImage"><div data-v-93e2444c="" class="glnBadge-wrap"><div data-v-93e2444c="" class="glnBadge-icon"><span data-v-6d1c5278="" data-v-93e2444c="" style="display: none;"></span> <span data-v-7ec1d915="" data-v-6d1c5278="" data-v-93e2444c="" style="font-size: 14px;"><svg data-v-7ec1d915="" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path data-v-7ec1d915="" fill="currentColor" fill-rule="nonzero" d="M7.6 5.5L18.163 12 7.6 18.5z"></path></svg></span></div> <span data-v-633c5b74="" data-v-93e2444c="" class="glnBadge-text text text--fNarrow text--stillness text--regular">
#       預告片
#     </span></div></div> <!----></a></div> <div data-v-3303a5bf="" class="detailListItem-info"><div data-v-3303a5bf="" class="detailListItem-details"><div data-v-3303a5bf="" class="detailListItem-detailsTop"><!----> <div data-v-3303a5bf="" class="detailListItem-titles"><h2 data-v-27ceb523="" data-v-3303a5bf="" class="detailListItem-title header header--sm header--primary header--ellipsis1">
#             闇黑電話2
#           </h2> <h3 data-v-27ceb523="" data-v-3303a5bf="" class="detailListItem-engTitle header header--xs header--primary header--ellipsis1">
#             Black Phone 2
#           </h3></div></div> <div data-v-3303a5bf="" class="detailListItem-revenue"><span data-v-633c5b74="" data-v-3303a5bf="" class="text text--f text--secondary text--regular text--ellipsis1"></span></div> <div data-v-3303a5bf="" class="detailListItem-status"><div data-v-6d436e16="" data-v-3303a5bf="" class="iconInfo detailListItem-iconInfo"><span data-v-6d436e16="" class="iconInfo-icon iconInfo-icon--popular"><span data-v-3303a5bf="" data-v-6d436e16=""></span> <span data-v-2652dcee="" data-v-3303a5bf="" data-v-6d436e16="" style="font-size: 18px;"><svg data-v-2652dcee="" width="18" height="18" viewBox="0 0 18 18" fill="none" xmlns="http://www.w3.org/2000/svg"><path data-v-2652dcee="" d="M9.00039 3.1499L10.6719 7.19852L14.8504 7.6189L11.7049 10.5415L12.6159 14.8499L9.00039 12.6075L5.38489 14.8499L6.29588 10.5415L3.15039 7.6189L7.32891 7.19852L9.00039 3.1499Z" fill="currentColor"></path></svg></span></span> <span data-v-633c5b74="" data-v-6d436e16="" class="iconInfo-text text text--f text--secondary text--regular">
#       8.6
#     </span></div> <span data-v-633c5b74="" data-v-3303a5bf="" class="text text--f text--secondary text--regular text--ellipsis1">
#           • 1小時54分 • 2025年10月17日上映
#         </span></div> <div data-v-3303a5bf="" class="detailListItem-category"><div data-v-93e2444c="" data-v-3303a5bf="" class="detailListItem-certificate glnBadge glnBadge-outlined--secondary"><div data-v-93e2444c="" class="glnBadge-wrap"><!----> <span data-v-633c5b74="" data-v-93e2444c="" class="glnBadge-text text text--fNarrow text--secondary text--regular">
#       輔15級
#     </span></div></div> <span data-v-633c5b74="" data-v-3303a5bf="" class="text text--f text--secondary text--regular text--ellipsis1">
#           恐怖
#         </span></div></div> <a data-v-3303a5bf="" href="/tw/v3/movie/KwMWjOo/1" class="detailListItem-bookingButton"><button data-v-29df5a2c="" class="actionButton theButton theButton--primary theButton--sm"><span data-v-29df5a2c="" class="theButton-icon"><!----> <!----> <!----> <!----> <!----></span> <span data-v-29df5a2c="" class="theButton-text">查看時刻表</span> <span data-v-29df5a2c="" class="theButton-icon"></span></button></a></div></div>

# %%
all_movie_info = []
for movie in movie_list:
    movie_name =  movie_list.find_element(By.CSS_SELECTOR, ".detailListItem-details .detailListItem-titles").text
    movie_grade = movie_list.find_element(By.CSS_SELECTOR, ".iconInfo.detailListItem-iconInfo").text
    movie_time = movie_list.find_element(By.CSS_SELECTOR, ".detailListItem-status > span").text
    movie_link = movie_list.find_element(By.CSS_SELECTOR, ".detailListItem-bookingButton").get_attribute("href")

    all_movie_info.append({
        "name" : movie_name,
        "grade" : movie_grade,
        "time" : movie_time,
        "link" : movie_link
    })
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 3
#       1 all_movie_info = []
#       2 for movie in movie_list:
# ----> 3     movie_name =  movie_list.find_element(By.CSS_SELECTOR, ".detailListItem-details .detailListItem-titles").text
#       4     movie_grade = movie_list.find_element(By.CSS_SELECTOR, ".iconInfo.detailListItem-iconInfo").text
#       5     movie_time = movie_list.find_element(By.CSS_SELECTOR, ".detailListItem-status > span").text
#
# AttributeError: 'list' object has no attribute 'find_element'

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import os
# from selenium.webdriver.chrome.service import Service
# from webdriver_manager.chrome import ChromeDriverManager

# 建立 Service 物件，指定 chromedriver.exe 的路徑
# service = Service('./chromedriver')

# 設定 Chrome 瀏覽器的選項
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized") # Chrome 瀏覽器在啟動時最大化視窗
options.add_argument("--incognito") # 無痕模式
options.add_argument("--disable-popup-blocking") # 停用 Chrome 的彈窗阻擋功能。\

star_mapping ={
    "M12 18.344l-5.81 3.609c-.147.091-.34.046-.43-.1-.043-.07-.057-.152-.04-.23l1.469-6.96-5.09-4.736c-.126-.118-.133-.316-.016-.442.052-.056.122-.091.198-.099l6.746-.68 2.684-6.513c.066-.16.249-.235.408-.17.077.032.138.094.17.17l2.684 6.514 6.746.68c.172.017.297.17.28.342-.008.075-.043.146-.099.198l-5.09 4.736 1.47 6.96c.036.169-.072.334-.24.37-.08.017-.161.002-.23-.04L12 18.343z": 2,
    "M12.12 2.024c.076.031.137.093.169.17l2.684 6.513 6.746.68c.172.017.297.17.28.342-.008.075-.043.146-.099.198l-5.09 4.736 1.47 6.96c.036.169-.072.334-.24.37-.08.017-.161.002-.23-.04L12 18.343l-5.81 3.61c-.147.091-.34.046-.43-.1-.043-.07-.057-.152-.04-.23l1.469-6.96-5.09-4.736c-.126-.118-.133-.316-.016-.442.052-.056.122-.091.198-.099l6.746-.68 2.684-6.513c.066-.16.249-.235.408-.17zM12 6.463v9.651l3.662 2.275-.925-4.383 3.316-3.086-4.398-.443L12 6.463z": 1,
    "M12.12 2.024c.076.031.137.093.169.17l2.684 6.513 6.746.68c.172.017.297.17.28.342-.008.075-.043.146-.099.198l-5.09 4.736 1.47 6.96c.036.169-.072.334-.24.37-.08.017-.161.002-.23-.04L12 18.343l-5.81 3.61c-.147.091-.34.046-.43-.1-.043-.07-.057-.152-.04-.23l1.469-6.96-5.09-4.736c-.126-.118-.133-.316-.016-.442.052-.056.122-.091.198-.099l6.746-.68 2.684-6.513c.066-.16.249-.235.408-.17zm1.6 8.365L12 6.216l-1.72 4.173-4.549.458 3.43 3.191-.961 4.546 3.8-2.36 3.799 2.36-.96-4.546 3.429-3.191-4.548-.458z": 0
}

# 建立 Chrome 瀏覽器物件
driver = webdriver.Chrome(options=options)
driver.get("https://today.line.me/tw/v2/movie/incinemas/playing")
import time
movie_list = driver.find_elements(By.CSS_SELECTOR, ".detailListItem.movieListing-movie")
last_movie = movie_list[-1]
while True:
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)

    movie_list = driver.find_elements(By.CSS_SELECTOR, ".detailListItem.movieListing-movie")
    
    if last_movie == movie_list[-1]:
        break
    last_movie = movie_list[-1]
    print(f"目前數量： {len(movie_list)}")

all_movie_info = []
for movie in movie_list:
    movie_name = movie.find_element(By.CSS_SELECTOR, ".detailListItem-details .detailListItem-titles").text
    movie_grade = movie.find_element(By.CSS_SELECTOR, ".iconInfo.detailListItem-iconInfo").text
    movie_time = movie.find_element(By.CSS_SELECTOR, ".detailListItem-status > span").text
    movie_link = movie.find_element(By.CSS_SELECTOR, ".detailListItem-bookingButton").get_attribute("href")
    
    all_movie_info.append({
        "Name": movie_name,
        "Average_grade": movie_grade,
        "Time": movie_time,
        "Link": movie_link
    })

if not os.path.exists():
    os.midir("movie_comment")
def get_all_comment(url):
    driver.get(url)
    driver.find_element(By.CSS_SELECTOR, "ul.tabs-list.movie li:nth-child(3)").click()
    time.sleep(1)
    comment_cards = driver.find_elements(By.CSS_SELECTOR, ".css-hnvcda")
    comment_info = []

    # 用for迴圈方法
    for comment_card in comment_cards:
        comment_user = comment_card.find_element(By.CSS_SELECTOR, ".ratingCommentItemUser").text
        # rating_container = comment_card.find_element(By.CSS_SELECTOR, ".ratingCommentItemUser-ratingContainer")
        stars = comment_card.find_elements(By.CSS_SELECTOR, ".ratingStar path")
        comment_date = comment_card.find_element(By.CSS_SELECTOR,".ratingCommentItemUser-createdTime.css-squ0i5").text
        comment = comment_card.find_element(By.CSS_SELECTOR, ".ratingCommentItemContent").text

        grade = 0
        # 用星星計算總分
        for star in stars:
            path_d = star.get_attribute("d")
            grade += star_mapping[path_d]


        comment_info.append({
            "comment_user": comment_user,
            "grade": grade,
            "comment_date": comment_date,
            "comment": comment
        })
    return comment_info

print(all_movie_info)
# Out:
# 目前數量： 30
# 目前數量： 40
# 目前數量： 50
# 目前數量： 60
# 目前數量： 70
# 目前數量： 80
# 目前數量： 90
 'Average_grade': '10', 'Time': '• 1小時58分 • 2025年11月07日上映', 'Link': 'https://today.line.me/tw/v3/movie/XYwJD89/1'}, {'Name': '去死吧，親愛的\nDie My Love', 'Average_grade': '8.6', 'Time': '• 1小時58分 • 2025年11月07日上映', 'Link': 'https://today.line.me/tw/v3/movie/7Nz3Qyk/1'}, {'Name': '左撇子女孩\nLeft-Handed Girl', 'Average_grade': '7.4', 'Time': '• 1小時48分 • 2025年10月31日上映', 'Link': 'https://today.line.me/tw/v3/movie/vXV0ZM0/1'}, {'Name': '女孩\nGirl', 'Average_grade': '8.5', 'Time': '• 2小時04分 • 2025年10月31日上映', 'Link': 'https://today.line.me/tw/v3/movie/PGNny9o/1'}, {'Name': '鬼聲泣3\nTee Yod 3', 'Average_grade': '8.3', 'Time': '• 1小時44分 • 2025年10月31日上映', 'Link': 'https://today.line.me/tw/v3/movie/eLOOzwK/1'}, {'Name': 'G-DRAGON IN CINEMA [Übermensch]\nG-DRAGON IN CINEMA [Übermensch]', 'Average_grade': '9.6', 'Time': '• 1小時46分 • 2025年10月29日上映', 'Link': 'https://today.line.me/tw/v3/movie/JPO827q/1'}, {'Name': "機動戰士鋼彈 鐵血孤兒 追尋兀爾德 -小小挑戰者的軌跡-\nSpecial Edition: Mobile Suit Gundam Iron-Blooded Orphans Urdr-Hunt ''-Path of the Little Challenger- ''", 'Average_grade': '0.0', 'Time': '• 1小時18分 • 2025年11月07日上映', 'Link': 'https://today.line.me/tw/v3/movie/Ya56JeN/1'}, {'Name': '天才琴手\nProdigieuses', 'Average_grade': '9.0', 'Time': '• 1小時49分 • 2025年11月14日上映', 'Link': 'https://today.line.me/tw/v3/movie/l2ngP6g/1'}, {'Name': '愉快動物餅 大電影\nDream Animals THE MOVIE', 'Average_grade': '0.0', 'Time': '• 1小時30分 • 2025年11月07日上映', 'Link': 'https://today.line.me/tw/v3/movie/kENqY1w/1'}, {'Name': '三分之愛\nYasuko, Songs of Days Past', 'Average_grade': '10', 'Time': '• 2小時08分 • 2025年11月14日上映', 'Link': 'https://today.line.me/tw/v3/movie/ZaoLoJg/1'}, {'Name': '鬼童伴\nMuslihat', 'Average_grade': '9.6', 'Time': '• 1小時30分 • 2025年11月07日上映', 'Link': 'https://today.lin ...

# %%
print(all_movie_info[0])
driver.get(all_movie_info[0]['Link'])
# Out:
# {'Name': '出神入化3\nNow You See Me：Now You Don’t', 'Average_grade': '6.2', 'Time': '• 1小時53分 • 2025年11月14日上映', 'Link': 'https://today.line.me/tw/v3/movie/JPMx3ox/1'}

# %%
driver.get(all_movie_info[0]['Link'])
time.sleep(2)
'''
因為 class 有重複 所以改用

'''
#driver.find_element(By.CSS_SELECTOR, "ul li:nth-child(3)") 找地 n 個元素
driver.find_element(By.CSS_SELECTOR, "ul.tabs-list.movie li:nth-child(3)").click()

# %%
star_mapping ={
    "M12.12 2.024c.076.031.137.093.169.17l2.684 6.513 6.746.68c.172.017.297.17.28.342-.008.075-.043.146-.099.198l-5.09 4.736 1.47 6.96c.036.169-.072.334-.24.37-.08.017-.161.002-.23-.04L12 18.343l-5.81 3.61c-.147.091-.34.046-.43-.1-.043-.07-.057-.152-.04-.23l1.469-6.96-5.09-4.736c-.126-.118-.133-.316-.016-.442.052-.056.122-.091.198-.099l6.746-.68 2.684-6.513c.066-.16.249-.235.408-.17zm1.6 8.365L12 6.216l-1.72 4.173-4.549.458 3.43 3.191-.961 4.546 3.8-2.36 3.799 2.36-.96-4.546 3.429-3.191-4.548-.458z": 0
}

def get_all_comment(url):
    driver.get(url)
    driver.find_element(By.CSS_SELECTOR, "ul.tabs-list.movie li:nth-child(3)").click()
    time.sleep(1)
    comment_cards = driver.find_elements(By.CSS_SELECTOR, ".css-hnvcda")
    comment_info = []

    # 用for迴圈方法
    for comment_card in comment_cards:
        comment_user = comment_card.find_element(By.CSS_SELECTOR, ".ratingCommentItemUser").text
        # rating_container = comment_card.find_element(By.CSS_SELECTOR, ".ratingCommentItemUser-ratingContainer")
        stars = comment_card.find_elements(By.CSS_SELECTOR, ".ratingStar path")
        comment_date = comment_card.find_element(By.CSS_SELECTOR,".ratingCommentItemUser-createdTime.css-squ0i5").text
        comment = comment_card.find_element(By.CSS_SELECTOR, ".ratingCommentItemContent").text

        grade = 0
        # 用星星計算總分
        for star in stars:
            path_d = star.get_attribute("d")
            grade += star_mapping[path_d]


        comment_info.append({
            "comment_user": comment_user,
            "grade": grade,
            "comment_date": comment_date,
            "comment": comment
        })
    return comment_info

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import os, json

# 設定 Chrome 瀏覽器的選項
options = webdriver.ChromeOptions()
options.add_argument("--start-maximized") # Chrome 瀏覽器在啟動時最大化視窗
options.add_argument("--incognito") # 無痕模式
options.add_argument("--disable-popup-blocking") # 停用 Chrome 的彈窗阻擋功能。

star_mapping = {
    "M12 18.344l-5.81 3.609c-.147.091-.34.046-.43-.1-.043-.07-.057-.152-.04-.23l1.469-6.96-5.09-4.736c-.126-.118-.133-.316-.016-.442.052-.056.122-.091.198-.099l6.746-.68 2.684-6.513c.066-.16.249-.235.408-.17.077.032.138.094.17.17l2.684 6.514 6.746.68c.172.017.297.17.28.342-.008.075-.043.146-.099.198l-5.09 4.736 1.47 6.96c.036.169-.072.334-.24.37-.08.017-.161.002-.23-.04L12 18.343z": 2,
    "M12.12 2.024c.076.031.137.093.169.17l2.684 6.513 6.746.68c.172.017.297.17.28.342-.008.075-.043.146-.099.198l-5.09 4.736 1.47 6.96c.036.169-.072.334-.24.37-.08.017-.161.002-.23-.04L12 18.343l-5.81 3.61c-.147.091-.34.046-.43-.1-.043-.07-.057-.152-.04-.23l1.469-6.96-5.09-4.736c-.126-.118-.133-.316-.016-.442.052-.056.122-.091.198-.099l6.746-.68 2.684-6.513c.066-.16.249-.235.408-.17zM12 6.463v9.651l3.662 2.275-.925-4.383 3.316-3.086-4.398-.443L12 6.463z": 1,
    "M12.12 2.024c.076.031.137.093.169.17l2.684 6.513 6.746.68c.172.017.297.17.28.342-.008.075-.043.146-.099.198l-5.09 4.736 1.47 6.96c.036.169-.072.334-.24.37-.08.017-.161.002-.23-.04L12 18.343l-5.81 3.61c-.147.091-.34.046-.43-.1-.043-.07-.057-.152-.04-.23l1.469-6.96-5.09-4.736c-.126-.118-.133-.316-.016-.442.052-.056.122-.091.198-.099l6.746-.68 2.684-6.513c.066-.16.249-.235.408-.17zm1.6 8.365L12 6.216l-1.72 4.173-4.549.458 3.43 3.191-.961 4.546 3.8-2.36 3.799 2.36-.96-4.546 3.429-3.191-4.548-.458z": 0
}

def get_all_comment(url):
    driver.get(url)
    driver.find_element(By.CSS_SELECTOR, 'ul.tabs-list.movie li:nth-child(3)').click()
    time.sleep(2)
    comment_cards = driver.find_elements(By.CSS_SELECTOR, ".css-hnvcda")
    comment_info = []
    for comment_card in comment_cards:
        comment_user = comment_card.find_element(By.CSS_SELECTOR, ".ratingCommentItemUser").text
        stars = comment_card.find_elements(By.CSS_SELECTOR, ".ratingStar path")
        comment_date = comment_card.find_element(By.CSS_SELECTOR, ".ratingCommentItemUser-createdTime.css-squ0i5").text
        comment = comment_card.find_element(By.CSS_SELECTOR, ".ratingCommentItemContent").text

        grade = 0
        # 用星星計算總分
        for star in stars:
            path_d = star.get_attribute('d')
            grade += star_mapping[path_d]

        comment_info.append({
            "comment_user": comment_user,
            "grade": grade,
            "comment_date": comment_date,
            "comment": comment
        })

    return comment_info


# 建立 Chrome 瀏覽器物件
driver = webdriver.Chrome(options=options)
driver.get("https://today.line.me/tw/v2/movie/incinemas/playing")

movie_list = driver.find_elements(By.CSS_SELECTOR, ".detailListItem.movieListing-movie")
last_movie = movie_list[-1]
print(f"目前數量: {len(movie_list)}")
while True:
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)
    # 取得新的所有元素
    movie_list = driver.find_elements(By.CSS_SELECTOR, ".detailListItem.movieListing-movie")
    if last_movie == movie_list[-1]:
        break
    
    last_movie = movie_list[-1]
    print(f"目前數量: {len(movie_list)}")

all_movie_info = []
for movie in movie_list:
    movie_name = movie.find_element(By.CSS_SELECTOR, ".detailListItem-details .detailListItem-titles").text
    movie_grade =  movie.find_element(By.CSS_SELECTOR, ".iconInfo.detailListItem-iconInfo").text
    movie_time = movie.find_element(By.CSS_SELECTOR, ".detailListItem-status > span").text
    movie_link = movie.find_element(By.CSS_SELECTOR, ".detailListItem-bookingButton").get_attribute("href")

    all_movie_info.append({
        "name": movie_name,
        "average_grade": movie_grade,
        "time": movie_time,
        "link": movie_link
    })

all_info = {}
for info in all_movie_info:
    try:
        comment_info: list = get_all_comment(info['link'])
    except Exception as e:
        with open("error_log.txt", 'a', encoding='utf-8') as f:
            f.write(f"{info['name']}-{info['link']}: {e}")
            
    all_info[info['name']] = {
        "average_grade": info['average_grade'],
        "movie_time": info['time'],
        "comments": comment_info
    }

with open(f"movie_comments.json", "w", encoding="utf-8") as f:
    json.dump(all_info, f, indent=4, ensure_ascii=False)
